# %% [markdown]
# # Workspace
# ### En este notebook se trabajá gracias

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# #### Analisis

# %% [markdown]
# #### Visualizaciones
